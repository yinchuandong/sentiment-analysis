# %%
import numpy as np
from numpy.testing import assert_array_equal
from rubixml.torch_textcnn import TextCNNSentimentClassifier
import dill

RANDOM_SEED = 2333
np.random.seed(RANDOM_SEED)

# %%
model = TextCNNSentimentClassifier(embed_dim=200, lr=0.001, dropout=0.8)

model.fit('./example_data/train.txt', nepoch=20, train_dev_ratio=0.8, batch_size=64)

sentences = ['how',
             'Wow... Loved this place.',
             'Crust is not good.',
             'Not tasty and the texture was just nasty.',
             'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
             'There was a warm feeling with the service and I felt like their guest for a special treat.']

last_result = model.predict_prob(sentences)
model.use_best_model()
best_result = model.predict_prob(sentences)


with open('./best_senti_model.pkl', 'wb') as f:
    dill.dump(model, f)

    
with open('./best_senti_model.pkl', 'rb') as f:
    new_model = dill.load(f)

new_result = new_model.predict_prob(sentences)

print(last_result)
print(best_result)
print(new_result)
# Out:
# ----------------------------------------------------------
# train: min words=1, max words=32, counter=Counter({1: 385, 0: 382})
# dev: min words=2, max words=28, counter=Counter({0: 101, 1: 91})
# ----------------------------------------------------------
#
#
# Epoch: 1 - Batch: 11 - loss: 0.796270  train acc: 0.52
# Evaluation -  dev acc: 0.68
#
# Saving best model, acc: 0.6823
#
# Epoch: 2 - Batch: 11 - loss: 0.516075  train acc: 0.87
# Evaluation -  dev acc: 0.69
#
# Saving best model, acc: 0.6927
#
# Epoch: 3 - Batch: 11 - loss: 0.461133  train acc: 0.79
# Evaluation -  dev acc: 0.69
#
# Epoch: 4 - Batch: 11 - loss: 0.272555  train acc: 0.95
# Evaluation -  dev acc: 0.73
#
# Saving best model, acc: 0.7344
#
# Epoch: 5 - Batch: 11 - loss: 0.218937  train acc: 0.98
# Evaluation -  dev acc: 0.71
#
# Epoch: 6 - Batch: 11 - loss: 0.146306  train acc: 0.98
# Evaluation -  dev acc: 0.71
#
# Epoch: 7 - Batch: 11 - loss: 0.102017  train acc: 1.00
# Evaluation -  dev acc: 0.72
#
# Epoch: 8 - Batch: 11 - loss: 0.077676  train acc: 1.00
# Evaluation -  dev acc: 0.71
#
# Epoch: 9 - Batch: 11 - loss: 0.061456  train acc: 1.00
# Evaluation -  dev acc: 0.71
#
# Epoch: 10 - Batch: 11 - loss: 0.049569  train acc: 1.00
# Evaluation -  dev acc: 0.73
#
# Epoch: 11 - Batch: 11 - loss: 0.032552  train acc: 1.00
# Evaluation -  dev acc: 0.74
#
# Saving best model, acc: 0.7448
#
# Epoch: 12 - Batch: 11 - loss: 0.036582  train acc: 1.00
# Evaluation -  dev acc: 0.72
#
# Epoch: 13 - Batch: 11 - loss: 0.021385  train acc: 1.00
# Evaluation -  dev acc: 0.73
#
# Epoch: 14 - Batch: 11 - loss: 0.017795  train acc: 1.00
# Evaluation -  dev acc: 0.74
#
# Epoch: 15 - Batch: 11 - loss: 0.014577  train acc: 1.00
# Evaluation -  dev acc: 0.75
#
# Saving best model, acc: 0.7500
#
# Epoch: 16 - Batch: 11 - loss: 0.008883  train acc: 1.00
# Evaluation -  dev acc: 0.74
#
# Epoch: 17 - Batch: 11 - loss: 0.008320  train acc: 1.00
# Evaluation -  dev acc: 0.75
#
# Epoch: 18 - Batch: 11 - loss: 0.008731  train acc: 1.00
# Evaluation -  dev acc: 0.75
#
# Epoch: 19 - Batch: 11 - loss: 0.009920  train acc: 1.00
# Evaluation -  dev acc: 0.76
#
# Saving best model, acc: 0.7552
#
# Epoch: 20 - Batch: 11 - loss: 0.008100  train acc: 1.00
# Evaluation -  dev acc: 0.76
#
# [0.5831989  0.00488843 0.9876507  0.9907692  0.00436587 0.96135634]
# [0.5850554  0.00601309 0.9883456  0.9906821  0.00522059 0.9619762 ]
# [0.5850554  0.00601309 0.9883456  0.9906821  0.00522059 0.9619762 ]
